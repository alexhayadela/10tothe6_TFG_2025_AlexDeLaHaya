# %%
import sys
from pathlib import Path
import pandas as pd 
project_root = Path.cwd().parent
sys.path.append(str(project_root))
from ingest.base import sqlite_connection


DB_PATH = Path.cwd().parent/ "data" / "news.db"

# %%
def load_news() -> pd.DataFrame:
    query = "SELECT * FROM news"
    
    with sqlite_connection(DB_PATH) as conn:
        df = pd.read_sql(query, conn, parse_dates=["date"])
    return df

# %%
df = load_news()
print(df.head(1))
df.shape
# Out:
#    id   section       date                                              title  \
# 0   1  mercados 2026-01-18  Bruselas estudia "ajustes" para "reforzar la r...
#
#                                                 body  \
# 0  La Comisión Europea estudia realizar "ajustes"...
#
#                                                  url        category  \
# 0  https://www.expansion.com/economia/2026/01/18/...  macro_economic
#
#   sentiment_gpt sentiment  relevance
# 0       neutral      None        0.3
# (121, 10)

# %%
def load_news_entities():
    query = "SELECT * FROM news_entities"
    
    with sqlite_connection(DB_PATH) as conn:
        df = pd.read_sql(query, conn, parse_dates=["date"])
    return df

# %%
df_ent = load_news_entities()
print(df_ent.head(1))
df_ent.shape
# Out:
#    news_id    ticker
# 0        3  Heymondo
# (307, 2)

# %%
def load_all():
    query = """
    SELECT * FROM news
    JOIN news_entities ON news.id == news_entities.news_id
    """
    with sqlite_connection(DB_PATH) as conn:
        df = pd.read_sql(query, conn, parse_dates=["date"])
    return df

# %%
df = load_all()
df.date.value_counts()
# Out:
# date
# 2026-01-21    73
# 2026-01-20    65
# 2026-01-19    51
# 2026-01-18     2
# Name: count, dtype: int64

# %%
df = load_all()
print(df.sort_values("date", ascending=False).head(5))
# Out:
#       id   section       date  \
# 190  232  economia 2026-01-21
# 134  211  economia 2026-01-21
# 136  213  economia 2026-01-21
# 137  214  economia 2026-01-21
# 138  214  economia 2026-01-21
#
#                                                  title  \
# 190  Conren Tramway se alía con ECE para invertir 4...
# 134  Grup Gepork supera los 100 millones de ventas ...
# 136  Adif también limita a 160 kilómetros por hora ...
# 137  Indra, Airbus, EM&E y Navantia copan el 90% de...
# 138  Indra, Airbus, EM&E y Navantia copan el 90% de...
#
#                                                   body  \
# 190  La promotora española Conren Trawmay se une al...
# 134  La compañía catalana de salud animal aumenta s...
# 136  Un maquinista ha avisado de cuatro defectos en...
# 137  El objetivo del Gobierno de aumentar el gasto ...
# 138  El objetivo del Gobierno de aumentar el gasto ...
#
#                                                    url          category  \
# 190  https://www.expansion.com/empresas/transporte/...  company_specific
# 134  https://www.expansion.com/catalunya/2026/01/21...  company_specific
# 136  https://www.expansion.com/valencia/2026/01/21/...    macro_economic
# 137  https://www.expansion.com/empresas/2026/01/21/...    macro_economic
# 138  https://www.expansion.com/empresas/2026/01/21/...    macro_economic
#
#     sentiment_gpt sentiment  relevance  news_id                  ticker
# 190      positive      None        0.7      232                     ECE
# 134      positive      None        0.7      211               ByteDance
# 136      negative      None        0.6      213                 Quinton
# 137      positive      None        0.8      214                 Netflix
# 138      positive      None        0.8      214  Warner Bros. Discovery

# %%
df = load_all()
df.shape
# Out:
# (191, 12)

# %%
df = df.drop_duplicates(["title", "body"])
df.shape
# Out:
# (86, 12)

# %%
df_all[]

# %%
df_all = load_all()
df_all
# Out:
#       id   section       date  \
# 0      3  economia 2026-01-18
# 1      4  economia 2026-01-18
# 2      7  economia 2026-01-19
# 3      7  economia 2026-01-19
# 4     10  mercados 2026-01-19
# ..   ...       ...        ...
# 186  229  economia 2026-01-21
# 187  230  economia 2026-01-21
# 188  231  economia 2026-01-21
# 189  232  economia 2026-01-21
# 190  232  economia 2026-01-21
#
#                                                  title  \
# 0    Heymondo pone rumbo a los 100 millones y mira ...
# 1    Rob Surgical invertirá 50 millones y abre en E...
# 2    Amazon recibe una reprimenda tras la quiebra d...
# 3    Amazon recibe una reprimenda tras la quiebra d...
# 4    Zurich lanza una opa de 7.700 millones de libr...
# ..                                                 ...
# 186  Adif mantiene suspendida la circulación de tre...
# 187  Torres: "Crecer y retribuir bien a todos los a...
# 188  Galán: "Iberdrola puede convertirse en la mayo...
# 189  Conren Tramway se alía con ECE para invertir 4...
# 190  Conren Tramway se alía con ECE para invertir 4...
#
#                                                   body  \
# 0    La firma barcelonesa especializada en la contr...
# 1    La 'spin-off' de la UPC y el Institut de Bioin...
# 2    El grupo tecnológico puede extraer cierto cons...
# 3    El grupo tecnológico puede extraer cierto cons...
# 4    El consejero delegado del grupo suizo señala q...
# ..                                                 ...
# 186
# 187  El presidente de BBVA desgrana en una entrevis...
# 188  El presidente de la mayor energética española ...
# 189  La promotora española Conren Trawmay se une al...
# 190  La promotora española Conren Trawmay se une al...
#
#                                                    url          category  \
# 0    https://www.expansion.com/catalunya/2026/01/18...  company_specific
# 1    https://www.expansion.com/catalunya/2026/01/16...  company_specific
# 2    https://www.expansion.com/economia/financial-t...  company_specific
# 3    https://www.expansion.com/economia/financial-t...  company_specific
# 4    https://www.expansion.com/economia/financial-t...  company_specific
# ..                                                 ...               ...
# 186  https://www.expansion.com/empresas/transporte/...  company_specific
# 187  https://www.expansion.com/empresas/banca/2026/...  company_specific
# 188  https://www.expansion.com/empresas/energia/202...  company_specific
# 189  https://www.expansion.com/empresas/transporte/...  company_specific
# 190  https://www.expansion.com/empresas/transporte/...  company_specific
#
#     sentiment_gpt sentiment  relevance  news_id          ticker
# 0        positive      None        0.9        3        Heymondo
# 1        positive      None        0.7        4    Rob Surgical
# 2        negative      None        0.7        7          Amazon
# 3        negative      None        0.7        7            Saks
# 4         neutral      None        0.8       10          Zurich
# ..            ...       ...        ...      ...             ...
# 186      negative      None        0.7      229            Adif
# 187      positive      None        0.7      230            BBVA
# 188      positive      None        0.7      231       Iberdrola
# 189      positive      None        0.7      232  Conren Tramway
# 190      positive      None        0.7      232             ECE
#
# [191 rows x 12 columns]

# %%
def load_news_for_tickers(
    tickers: list[str],
    start=None,
    end=None
) -> pd.DataFrame:

    placeholders = ",".join("?" * len(tickers))

    query = f"""
    SELECT
        n.date,
        ne.ticker,
        n.sentiment,
        n.relevance
    FROM news n
    JOIN news_entities ne ON n.id = ne.news_id
    WHERE ne.ticker IN ({placeholders})
    """

    params = tickers

    if start:
        query += " AND n.date >= ?"
        params.append(start)
    if end:
        query += " AND n.date <= ?"
        params.append(end)

    with sqlite_connection(DB_PATH) as conn:
        df = pd.read_sql(query, conn, params=params, parse_dates=["date"])
    return df

# %%
def load_daily_sentiment() -> pd.DataFrame:
    query = """
    SELECT
        ne.ticker,
        n.date,
        AVG(n.sentiment) AS avg_sentiment,
        AVG(n.relevance) AS avg_relevance,
        COUNT(*) AS n_news
    FROM news n
    JOIN news_entities ne ON n.id = ne.news_id
    GROUP BY ne.ticker, n.date
    """
    with sqlite_connection(DB_PATH) as conn:
        df = pd.read_sql(query, conn, parse_dates=["date"])
    return df
