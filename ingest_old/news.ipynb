# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))
from news.news_rss import fetch_rss

# %%
df = fetch_rss()
df
# Out:
#       section                                              title  \
# 0    mercados  El Ibex gana un 0,35% en la semana y conquista...
# 1    mercados  Los bajistas ponen en su punto de mira a las e...
# 2    mercados           Cómo invertir en Bolsa con éxito en 2026
# 3    mercados  Los fondos de Bolsa favoritos de los grandes i...
# 4    mercados  Santander, BBVA y CaixaBank asaltan el 'top' e...
# ..        ...                                                ...
# 154  economia  Santa Bárbara recrudece la pugna judicial con ...
# 155  economia  La estación de Atocha sufre retrasos de más de...
# 156  economia  OpenAI firma un acuerdo  de 8.600 millones con...
# 157  economia  Uber Eats dejará de trabajar con repartidores ...
# 158  economia  El gigante chino Geely, dueño de Volvo, Smart ...
#
#                                                summary        date  \
# 0    Las Bolsas europeas han despedido la sesión co...  2026-01-16
# ...

# %%
now = df.iloc[156]
print(now.tags)
# Out:
# ['Empresas', 'Economía Digital', 'Artículos Miriam Prieto']
